# %% [markdown]
# # Day 19: A Series of Tubes
#
# [Link to Advent of Code 2017 - Day 19](https://adventofcode.com/2017/day/19)
#
#
# Somehow, a network packet got lost and ended up here. It's trying to follow a routing diagram (your puzzle input), but it's confused about where to go.
#
# Its starting point is just off the top of the diagram. Lines (drawn with |, -, and +) show the path it needs to take, starting by going down onto the only line connected to the top of the diagram. It needs to follow this path until it reaches the end (located somewhere within the diagram) and stop there.
#
# Sometimes, the lines cross over each other; in these cases, it needs to continue going the same direction, and only turn left or right when there's no other option. In addition, someone has left letters on the line; these also don't change its direction, but it can use them to keep track of where it's been. For example:
# ```
#      |
#      |  +--+
#      A  |  C
#  F---|----E|--+
#      |  |  |  D
#      +B-+  +--+
#
# ```
# Given this diagram, the packet needs to take the following path:
#
# Starting at the only line touching the top of the diagram, it must go down, pass through A, and continue onward to the first +.
# Travel right, up, and right, passing through B in the process.
# Continue down (collecting C), right, and up (collecting D).
# Finally, go all the way left through E and stopping at F.
# Following the path to the end, the letters it sees on its path are ABCDEF.
#
# The little packet looks up at you, hoping you can help it find the way.
#
# ### Part One:
#
# What letters will it see (in the order it would see them) if it follows the path? (The routing diagram is very wide; make sure you view it without line wrapping.)
#
# ### Part Two:
#
# The packet is curious how many steps it needs to go.
#
# For example, using the same routing diagram from the example above...
# ```
#      |
#      |  +--+
#      A  |  C
#  F---|--|-E---+
#      |  |  |  D
#      +B-+  +--+
# ```
# ...the packet would go:
#
# - 6 steps down (including the first line at the top of the diagram).
# - 3 steps right.
# - 4 steps up.
# - 3 steps right.
# - 4 steps down.
# - 3 steps right.
# - 2 steps up.
# - 13 steps left (including the F it stops on).
#
# This would result in a total of 38 steps.
#
# How many steps does the packet need to go?

# %%
with open('Inputs\day_19.txt')         as f:puz     = [list(l.rstrip('\n')) for l in f.readlines()]
with open('Inputs\day_19_sample.txt')  as f:sample  = [list(l.rstrip('\n')) for l in f.readlines()]

# Part One answer = abc / Part Two answer = 8    
test = [[' ',' ',' ',' ',' ','|', ' '] \
       ,[' ',' ',' ',' ',' ','a', ' '] \
       ,[' ','+','c','b','-','+', ' '] \
       ,[' ','|',' ',' ',' ',' ', ' '] \
       ,[' ',' ',' ',' ',' ',' ', ' ']] 

def move_through_map(Map: 'list of lists (2d array)') -> 'prints solution':
    '''
    Function to navigate through the puzzle input (the 'Map') one step at a time
    - each time a letter is encountered it is added tot he 'solution' string
    - each time a cross road is encountered the direction changes
    '''
    
    # setting starting x/y coord, starting direction and empty solution string
    y = 0
    x = Map[y].index('|')
    direction = 's'
    solution = ''
    steps = 0
    
    # continue to move through the input Map until a blank space is reached 
    while Map[y][x] != ' ':
        
        # update x or y coord
        if   direction == 'n': y -= 1
        elif direction == 'e': x += 1
        elif direction == 's': y += 1
        elif direction == 'w': x -= 1
            
        # if a letter then add to the solution string
        if Map[y][x].isalpha():
            solution += Map[y][x]
            
        # if a crossroad ('+') then change direction, 
        # as it's always a 90° shift so horizontal plane has to switch to vertical and vice versa
        # also there is a blank border around the Map so -/+ 1 to either the x/y coord should never put us out of bounds
        elif Map[y][x] == '+':
            if direction in ('n', 's'):
                if   Map[y][x+1] != ' ': direction = 'e'
                elif Map[y][x-1] != ' ': direction = 'w'
            elif direction in ('e', 'w'):
                if   Map[y-1][x] != ' ': direction = 'n'
                elif Map[y+1][x] != ' ': direction = 's'
        
        steps += 1
                    
    print(f'Part One: {solution}\nPart Two: {steps}')
    
move_through_map(puz)
# Out:
# Part One: LXWCKGRAOY
# Part Two: 17302
